# %% [markdown]
# ## Import Dependencies

# %%
import requests
from bs4 import BeautifulSoup, Comment
from time import sleep
import re
import pandas as pd

# %% [markdown]
# ## Create a list with the NFL Summaries Pages from Pro Football Reference
# ### List contains years 2012 through 2021

# %%
mainPages = ['https://www.pro-football-reference.com/years/2018/#all_week_games',
             'https://www.pro-football-reference.com/years/2019/#all_week_games',
             'https://www.pro-football-reference.com/years/2020/#all_week_games',
             'https://www.pro-football-reference.com/years/2021/#all_week_games',
             'https://www.pro-football-reference.com/years/2022/#all_week_games']

# %% [markdown]
# ## Scrape each page to get the URL for every week of the 10 seasons

# %%
weekURLs = []
baseURL = 'https://www.pro-football-reference.com'
for summary in mainPages:
    mainPage = requests.get(summary)
    sleep(2)
    mainSoup = BeautifulSoup(mainPage.content, 'html.parser')
    summaries = mainSoup.find(id='all_week_games')
    weeks = list(summaries.children)[4]
    weeksData = BeautifulSoup(weeks, 'html.parser')
    for a in weeksData.find_all('a',href=True):
        weekURLs.append(a['href'])
weekURLs = [baseURL + week for week in weekURLs]
weekURLs
# Out:
# ['https://www.pro-football-reference.com/years/2020/week_1.htm',
#  'https://www.pro-football-reference.com/years/2020/week_2.htm',
#  'https://www.pro-football-reference.com/years/2020/week_3.htm',
#  'https://www.pro-football-reference.com/years/2020/week_4.htm',
#  'https://www.pro-football-reference.com/years/2020/week_5.htm',
#  'https://www.pro-football-reference.com/years/2020/week_6.htm',
#  'https://www.pro-football-reference.com/years/2020/week_7.htm',
#  'https://www.pro-football-reference.com/years/2020/week_8.htm',
#  'https://www.pro-football-reference.com/years/2020/week_9.htm',
#  'https://www.pro-football-reference.com/years/2020/week_10.htm',
#  'https://www.pro-football-reference.com/years/2020/week_11.htm',
#  'https://www.pro-football-reference.com/years/2020/week_12.htm',
#  'https://www.pro-football-reference.com/years/2020/week_13.htm',
#  'https://www.pro-football-reference.com/years/2020/week_14.htm',
#  'https://www.pro-football-reference.com/years/2020/week_15.htm',
#  'https://www.pro-football-reference.com/years/2020/week_16.htm',
#  'https://www.pro-football-reference.com/years/2020/week_17.htm',
#  'https://www.pro-football-reference.com/years/2020/week_18.htm',
#  'https://www.pro-football-reference.com/years/2020/week_19.htm',
#  'https://www.pro-football-reference.com/years/2020/week_20.htm',
#  'https://www.pro-football-reference.com/years/2020/week_21.htm']

# %% [markdown]
# ## Scrape each week to get the URL for every game of every week

# %%
# Scrape the URL for each game of each week of every season
gameURLs = []
for week in weekURLs:
    gamePage = requests.get(week)
    sleep(3)
    gameSoup = BeautifulSoup(gamePage.content, 'html.parser')
    summaries = gameSoup.find(class_='game_summaries')
    for a in summaries.find_all('a',href=True):
        href = str(a['href'])
        if 'box' in href:
            gameURLs.append(href)
gameURLs = [baseURL + game for game in gameURLs]
gameURLs
# Out:
# ['https://www.pro-football-reference.com/boxscores/202009100kan.htm',
#  'https://www.pro-football-reference.com/boxscores/202009130atl.htm',
#  'https://www.pro-football-reference.com/boxscores/202009130buf.htm',
#  'https://www.pro-football-reference.com/boxscores/202009130car.htm',
#  'https://www.pro-football-reference.com/boxscores/202009130det.htm',
#  'https://www.pro-football-reference.com/boxscores/202009130jax.htm',
#  'https://www.pro-football-reference.com/boxscores/202009130min.htm',
#  'https://www.pro-football-reference.com/boxscores/202009130nwe.htm',
#  'https://www.pro-football-reference.com/boxscores/202009130rav.htm',
#  'https://www.pro-football-reference.com/boxscores/202009130was.htm',
#  'https://www.pro-football-reference.com/boxscores/202009130cin.htm',
#  'https://www.pro-football-reference.com/boxscores/202009130nor.htm',
#  'https://www.pro-football-reference.com/boxscores/202009130sfo.htm',
#  'https://www.pro-football-reference.com/boxscores/202009130ram.htm',
#  'https://www.pro-football-reference.com/boxscores/202009140nyg.htm',
#  'https://www.pro-football-reference.com/boxscores/202009140den.htm',
#  'https://www.pro-football-reference.com/boxscores/202009170cle.htm',
#  'https://www.pro-football-reference.com/boxscores/202009200chi.htm',
#  'https://www.pro-football-reference.com/boxscores/202009200clt.htm',
#  'https://www.pro-football-reference.com/boxscores/202009200dal.htm',
#  'https://www.pro-football-reference.com/boxscores/202009200gnb.htm',
#  'https://www.pro-football-reference.com/boxscores/202009200mia.htm',
#  'https://www.pro-football-reference.com/boxscores/202009200nyj.htm',
#  'https://www.pro-football-reference.com/boxscores/202009200oti.htm',
#  'https://www.pro-football-reference.com/boxscores/202009200phi.htm',
#  'https://www.pro-football-reference.com/boxscores/202009200pit.htm',
#  'https://www.pro-football-reference.com/boxscores/202009200tam.htm',
#  'https://www.pro-football-reference.com/boxscores/202009200crd.htm',
#  'https://www.pro-football-reference.com/boxscores/202009200htx.htm',
#  'https://www.pro-football-reference.com/boxscores/202009200sdg.htm',
#  'https://www.pro-football-reference.com/boxscores/202009200sea.htm',
#  'https://www.pro-football-reference.com/boxscores/202009210rai.htm',
#  'https://www.pro-football-reference.com/boxscores/202009240jax.htm',
#  'https://www.pro-football-reference.com/boxscores/202009270atl.htm',
#  'https://www.pro-football-reference.com/boxscores/202009270buf.htm',
#  'https://www.pro-football-reference.com/boxscores/202009270cle.htm',
#  'https://www.pro-football-reference.com/boxscores/202009270min.htm',
#  'https://www.pro-football-reference.com/boxscores/202009270nwe.htm',
#  'https://www.pro-football-reference.com/boxscores/202009270nyg.htm',
#  'https://www.pro-football-reference.com/boxscores/202009270phi.htm',
#  'https://www.pro-football-reference.com/boxscores/202009270pit.htm',
#  'https://www.pro-football-reference.com/boxscores/202009270clt.htm',
#  'https://www.pro-football-reference.com/boxscores/202009270sdg.htm',
#  'https://www.pro-football-reference.com/boxscores/202009270crd.htm',
#  'https://www.pro-football-reference.com/boxscores/202009270den.htm',
#  'https://www.pro-football-reference.com/boxscores/202009270sea.htm',
#  'https://www.pro-football-reference.com/boxscores/202009270nor.htm',
#  'https://www.pro-football-reference.com/boxscores/202009280rav.htm',
#  'https://www.pro-football-reference.com/boxscores/202010010nyj.htm',
#  'https://www.pro-football-reference.com/boxscores/202010040car.htm',
#  'https://www.pro-football-reference.com/boxscores/202010040chi.htm',
#  'https://www.pro-football-reference.com/boxscores/202010040cin.htm',
#  'https://www.pro-football-reference.com/boxscores/202010040dal.htm',
#  'https://www.pro-football-reference.com/boxscores/202010040det.htm',
#  'https://www.pro-football-reference.com/boxscores/202010040htx.htm',
#  'https://www.pro-football-reference.com/boxscores/202010040mia.htm',
#  'https://www.pro-football-reference.com/boxscores/202010040tam.htm',
#  'https://www.pro-football-reference.com/boxscores/202010040was.htm',
#  'https://www.pro-football-reference.com/boxscores/202010040ram.htm',
#  'https://www.pro-football-reference.com/boxscores/202010040rai.htm',
#  'https://www.pro-football-reference.com/boxscores/202010040sfo.htm',
#  'https://www.pro-football-reference.com/boxscores/202010050kan.htm',
#  'https://www.pro-football-reference.com/boxscores/202010050gnb.htm',
#  'https://www.pro-football-reference.com/boxscores/202010080chi.htm',
#  'https://www.pro-football-reference.com/boxscores/202010110atl.htm',
#  'https://www.pro-football-reference.com/boxscores/202010110htx.htm',
#  'https://www.pro-football-reference.com/boxscores/202010110kan.htm',
#  'https://www.pro-football-reference.com/boxscores/202010110nyj.htm',
#  'https://www.pro-football-reference.com/boxscores/202010110pit.htm',
#  'https://www.pro-football-reference.com/boxscores/202010110rav.htm',
#  'https://www.pro-football-reference.com/boxscores/202010110was.htm',
#  'https://www.pro-football-reference.com/boxscores/202010110sfo.htm',
#  'https://www.pro-football-reference.com/boxscores/202010110cle.htm',
#  'https://www.pro-football-reference.com/boxscores/202010110dal.htm',
#  'https://www.pro-football-reference.com/boxscores/202010110sea.htm',
#  'https://www.pro-football-reference.com/boxscores/202010120nor.htm',
#  'https://www.pro-football-reference.com/boxscores/202010130oti.htm',
#  'https://www.pro-football-reference.com/boxscores/202010180car.htm',
#  'https://www.pro-football-reference.com/boxscores/202010180clt.htm',
#  'https://www.pro-football-reference.com/boxscores/202010180jax.htm',
#  'https://www.pro-football-reference.com/boxscores/202010180min.htm',
#  'https://www.pro-football-reference.com/boxscores/202010180nwe.htm',
#  'https://www.pro-football-reference.com/boxscores/202010180nyg.htm',
#  'https://www.pro-football-reference.com/boxscores/202010180oti.htm',
#  'https://www.pro-football-reference.com/boxscores/202010180phi.htm',
#  'https://www.pro-football-reference.com/boxscores/202010180pit.htm',
#  'https://www.pro-football-reference.com/boxscores/202010180mia.htm',
#  'https://www.pro-football-reference.com/boxscores/202010180tam.htm',
#  'https://www.pro-football-reference.com/boxscores/202010180sfo.htm',
#  'https://www.pro-football-reference.com/boxscores/202010190buf.htm',
#  'https://www.pro-football-reference.com/boxscores/202010190dal.htm',
#  'https://www.pro-football-reference.com/boxscores/202010220phi.htm',
#  'https://www.pro-football-reference.com/boxscores/202010250atl.htm',
#  'https://www.pro-football-reference.com/boxscores/202010250cin.htm',
#  'https://www.pro-football-reference.com/boxscores/202010250htx.htm',
#  'https://www.pro-football-reference.com/boxscores/202010250nor.htm',
#  'https://www.pro-football-reference.com/boxscores/202010250nyj.htm',
#  'https://www.pro-football-reference.com/boxscores/202010250oti.htm',
#  'https://www.pro-football-reference.com/boxscores/202010250was.htm',
#  'https://www.pro-football-reference.com/boxscores/202010250rai.htm',
#  'https://www.pro-football-reference.com/boxscores/202010250den.htm',
#  'https://www.pro-football-reference.com/boxscores/202010250nwe.htm',
#  'https://www.pro-football-reference.com/boxscores/202010250sdg.htm',
#  'https://www.pro-football-reference.com/boxscores/202010250crd.htm',
#  'https://www.pro-football-reference.com/boxscores/202010260ram.htm',
#  'https://www.pro-football-reference.com/boxscores/202010290car.htm',
#  'https://www.pro-football-reference.com/boxscores/202011010buf.htm',
#  'https://www.pro-football-reference.com/boxscores/202011010cin.htm',
#  'https://www.pro-football-reference.com/boxscores/202011010cle.htm',
#  'https://www.pro-football-reference.com/boxscores/202011010det.htm',
#  'https://www.pro-football-reference.com/boxscores/202011010gnb.htm',
#  'https://www.pro-football-reference.com/boxscores/202011010kan.htm',
#  'https://www.pro-football-reference.com/boxscores/202011010mia.htm',
#  'https://www.pro-football-reference.com/boxscores/202011010rav.htm',
#  'https://www.pro-football-reference.com/boxscores/202011010den.htm',
#  'https://www.pro-football-reference.com/boxscores/202011010chi.htm',
#  'https://www.pro-football-reference.com/boxscores/202011010sea.htm',
#  'https://www.pro-football-reference.com/boxscores/202011010phi.htm',
#  'https://www.pro-football-reference.com/boxscores/202011020nyg.htm',
#  'https://www.pro-football-reference.com/boxscores/202011050sfo.htm',
#  'https://www.pro-football-reference.com/boxscores/202011080atl.htm',
#  'https://www.pro-football-reference.com/boxscores/202011080buf.htm',
#  'https://www.pro-football-reference.com/boxscores/202011080clt.htm',
#  'https://www.pro-football-reference.com/boxscores/202011080jax.htm',
#  'https://www.pro-football-reference.com/boxscores/202011080kan.htm',
#  'https://www.pro-football-reference.com/boxscores/202011080min.htm',
#  'https://www.pro-football-reference.com/boxscores/202011080oti.htm',
#  'https://www.pro-football-reference.com/boxscores/202011080was.htm',
#  'https://www.pro-football-reference.com/boxscores/202011080sdg.htm',
#  'https://www.pro-football-reference.com/boxscores/202011080crd.htm',
#  'https://www.pro-football-reference.com/boxscores/202011080dal.htm',
#  'https://www.pro-football-reference.com/boxscores/202011080tam.htm',
#  'https://www.pro-football-reference.com/boxscores/202011090nyj.htm',
#  'https://www.pro-football-reference.com/boxscores/202011120oti.htm',
#  'https://www.pro-football-reference.com/boxscores/202011150car.htm',
#  'https://www.pro-football-reference.com/boxscores/202011150cle.htm',
#  'https://www.pro-football-reference.com/boxscores/202011150det.htm',
#  'https://www.pro-football-reference.com/boxscores/202011150gnb.htm',
#  'https://www.pro-football-reference.com/boxscores/202011150nyg.htm',
#  'https://www.pro-football-reference.com/boxscores/202011150crd.htm',
#  'https://www.pro-football-reference.com/boxscores/202011150mia.htm',
#  'https://www.pro-football-reference.com/boxscores/202011150rai.htm',
#  'https://www.pro-football-reference.com/boxscores/202011150nor.htm',
#  'https://www.pro-football-reference.com/boxscores/202011150pit.htm',
#  'https://www.pro-football-reference.com/boxscores/202011150ram.htm',
#  'https://www.pro-football-reference.com/boxscores/202011150nwe.htm',
#  'https://www.pro-football-reference.com/boxscores/202011160chi.htm',
#  'https://www.pro-football-reference.com/boxscores/202011190sea.htm',
#  'https://www.pro-football-reference.com/boxscores/202011220car.htm',
#  'https://www.pro-football-reference.com/boxscores/202011220cle.htm',
#  'https://www.pro-football-reference.com/boxscores/202011220htx.htm',
#  'https://www.pro-football-reference.com/boxscores/202011220jax.htm',
#  'https://www.pro-football-reference.com/boxscores/202011220nor.htm',
#  'https://www.pro-football-reference.com/boxscores/202011220rav.htm',
#  'https://www.pro-football-reference.com/boxscores/202011220was.htm',
#  'https://www.pro-football-reference.com/boxscores/202011220den.htm',
#  'https://www.pro-football-reference.com/boxscores/202011220sdg.htm',
#  'https://www.pro-football-reference.com/boxscores/202011220clt.htm',
#  'https://www.pro-football-reference.com/boxscores/202011220min.htm',
#  'https://www.pro-football-reference.com/boxscores/202011220rai.htm',
#  'https://www.pro-football-reference.com/boxscores/202011230tam.htm',
#  'https://www.pro-football-reference.com/boxscores/202011260det.htm',
#  'https://www.pro-football-reference.com/boxscores/202011260dal.htm',
#  'https://www.pro-football-reference.com/boxscores/202011290atl.htm',
#  'https://www.pro-football-reference.com/boxscores/202011290buf.htm',
#  'https://www.pro-football-reference.com/boxscores/202011290cin.htm',
#  'https://www.pro-football-reference.com/boxscores/202011290clt.htm',
#  'https://www.pro-football-reference.com/boxscores/202011290jax.htm',
#  'https://www.pro-football-reference.com/boxscores/202011290min.htm',
#  'https://www.pro-football-reference.com/boxscores/202011290nwe.htm',
#  'https://www.pro-football-reference.com/boxscores/202011290nyj.htm',
#  'https://www.pro-football-reference.com/boxscores/202011290den.htm',
#  'https://www.pro-football-reference.com/boxscores/202011290ram.htm',
#  'https://www.pro-football-reference.com/boxscores/202011290tam.htm',
#  'https://www.pro-football-reference.com/boxscores/202011290gnb.htm',
#  'https://www.pro-football-reference.com/boxscores/202011300phi.htm',
#  'https://www.pro-football-reference.com/boxscores/202012020pit.htm',
#  'https://www.pro-football-reference.com/boxscores/202012060atl.htm',
#  'https://www.pro-football-reference.com/boxscores/202012060chi.htm',
#  'https://www.pro-football-reference.com/boxscores/202012060htx.htm',
#  'https://www.pro-football-reference.com/boxscores/202012060mia.htm',
#  'https://www.pro-football-reference.com/boxscores/202012060min.htm',
#  'https://www.pro-football-reference.com/boxscores/202012060nyj.htm',
#  'https://www.pro-football-reference.com/boxscores/202012060oti.htm',
#  'https://www.pro-football-reference.com/boxscores/202012060crd.htm',
#  'https://www.pro-football-reference.com/boxscores/202012060sea.htm',
#  'https://www.pro-football-reference.com/boxscores/202012060gnb.htm',
#  'https://www.pro-football-reference.com/boxscores/202012060sdg.htm',
#  'https://www.pro-football-reference.com/boxscores/202012060kan.htm',
#  'https://www.pro-football-reference.com/boxscores/202012070pit.htm',
#  'https://www.pro-football-reference.com/boxscores/202012070sfo.htm',
#  'https://www.pro-football-reference.com/boxscores/202012080rav.htm',
#  'https://www.pro-football-reference.com/boxscores/202012100ram.htm',
#  'https://www.pro-football-reference.com/boxscores/202012130car.htm',
#  'https://www.pro-football-reference.com/boxscores/202012130chi.htm',
#  'https://www.pro-football-reference.com/boxscores/202012130cin.htm',
#  'https://www.pro-football-reference.com/boxscores/202012130jax.htm',
#  'https://www.pro-football-reference.com/boxscores/202012130mia.htm',
#  'https://www.pro-football-reference.com/boxscores/202012130nyg.htm',
#  'https://www.pro-football-reference.com/boxscores/202012130tam.htm',
#  'https://www.pro-football-reference.com/boxscores/202012130rai.htm',
#  'https://www.pro-football-reference.com/boxscores/202012130sea.htm',
#  'https://www.pro-football-reference.com/boxscores/202012130det.htm',
#  'https://www.pro-football-reference.com/boxscores/202012130phi.htm',
#  'https://www.pro-football-reference.com/boxscores/202012130sdg.htm',
#  'https://www.pro-football-reference.com/boxscores/202012130sfo.htm',
#  'https://www.pro-football-reference.com/boxscores/202012130buf.htm',
#  'https://www.pro-football-reference.com/boxscores/202012140cle.htm',
#  'https://www.pro-football-reference.com/boxscores/202012170rai.htm',
#  'https://www.pro-football-reference.com/boxscores/202012190den.htm',
#  'https://www.pro-football-reference.com/boxscores/202012190gnb.htm',
#  'https://www.pro-football-reference.com/boxscores/202012200atl.htm',
#  'https://www.pro-football-reference.com/boxscores/202012200clt.htm',
#  'https://www.pro-football-reference.com/boxscores/202012200dal.htm',
#  'https://www.pro-football-reference.com/boxscores/202012200mia.htm',
#  'https://www.pro-football-reference.com/boxscores/202012200min.htm',
#  'https://www.pro-football-reference.com/boxscores/202012200oti.htm',
#  'https://www.pro-football-reference.com/boxscores/202012200rav.htm',
#  'https://www.pro-football-reference.com/boxscores/202012200was.htm',
#  'https://www.pro-football-reference.com/boxscores/202012200crd.htm',
#  'https://www.pro-football-reference.com/boxscores/202012200ram.htm',
#  'https://www.pro-football-reference.com/boxscores/202012200nor.htm',
#  'https://www.pro-football-reference.com/boxscores/202012200nyg.htm',
#  'https://www.pro-football-reference.com/boxscores/202012210cin.htm',
#  'https://www.pro-football-reference.com/boxscores/202012250nor.htm',
#  'https://www.pro-football-reference.com/boxscores/202012260det.htm',
#  'https://www.pro-football-reference.com/boxscores/202012260crd.htm',
#  'https://www.pro-football-reference.com/boxscores/202012260rai.htm',
#  'https://www.pro-football-reference.com/boxscores/202012270htx.htm',
#  'https://www.pro-football-reference.com/boxscores/202012270jax.htm',
#  'https://www.pro-football-reference.com/boxscores/202012270kan.htm',
#  'https://www.pro-football-reference.com/boxscores/202012270nyj.htm',
#  'https://www.pro-football-reference.com/boxscores/202012270pit.htm',
#  'https://www.pro-football-reference.com/boxscores/202012270rav.htm',
#  'https://www.pro-football-reference.com/boxscores/202012270sdg.htm',
#  'https://www.pro-football-reference.com/boxscores/202012270was.htm',
#  'https://www.pro-football-reference.com/boxscores/202012270dal.htm',
#  'https://www.pro-football-reference.com/boxscores/202012270sea.htm',
#  'https://www.pro-football-reference.com/boxscores/202012270gnb.htm',
#  'https://www.pro-football-reference.com/boxscores/202012280nwe.htm',
#  'https://www.pro-football-reference.com/boxscores/202101030buf.htm',
#  'https://www.pro-football-reference.com/boxscores/202101030cin.htm',
#  'https://www.pro-football-reference.com/boxscores/202101030cle.htm',
#  'https://www.pro-football-reference.com/boxscores/202101030det.htm',
#  'https://www.pro-football-reference.com/boxscores/202101030nwe.htm',
#  'https://www.pro-football-reference.com/boxscores/202101030nyg.htm',
#  'https://www.pro-football-reference.com/boxscores/202101030tam.htm',
#  'https://www.pro-football-reference.com/boxscores/202101030car.htm',
#  'https://www.pro-football-reference.com/boxscores/202101030chi.htm',
#  'https://www.pro-football-reference.com/boxscores/202101030clt.htm',
#  'https://www.pro-football-reference.com/boxscores/202101030den.htm',
#  'https://www.pro-football-reference.com/boxscores/202101030htx.htm',
#  'https://www.pro-football-reference.com/boxscores/202101030kan.htm',
#  'https://www.pro-football-reference.com/boxscores/202101030ram.htm',
#  'https://www.pro-football-reference.com/boxscores/202101030sfo.htm',
#  'https://www.pro-football-reference.com/boxscores/202101030phi.htm',
#  'https://www.pro-football-reference.com/boxscores/202101090buf.htm',
#  'https://www.pro-football-reference.com/boxscores/202101090sea.htm',
#  'https://www.pro-football-reference.com/boxscores/202101090was.htm',
#  'https://www.pro-football-reference.com/boxscores/202101100oti.htm',
#  'https://www.pro-football-reference.com/boxscores/202101100nor.htm',
#  'https://www.pro-football-reference.com/boxscores/202101100pit.htm',
#  'https://www.pro-football-reference.com/boxscores/202101160gnb.htm',
#  'https://www.pro-football-reference.com/boxscores/202101160buf.htm',
#  'https://www.pro-football-reference.com/boxscores/202101170kan.htm',
#  'https://www.pro-football-reference.com/boxscores/202101170nor.htm',
#  'https://www.pro-football-reference.com/boxscores/202101240gnb.htm',
#  'https://www.pro-football-reference.com/boxscores/202101240kan.htm',
#  'https://www.pro-football-reference.com/boxscores/202102070tam.htm']

# %% [markdown]
# ## Create an empty dataframe for the scraped data

# %%
df = pd.DataFrame(columns=['wonToss','roof','surface','attendance','weather','vegasLine','over/under',
                           'homeScore','awayScore','homeRecord','awayRecord','date','time',
                           'stadium','teams(away:home)','firstDowns','rush-yds-tds','cmp-att-yd-td-int',
                           'sacked-yrds','passYards','totalYards','fumbles-lost','turnovers','penalties-yrds',
                           'thirdDownConv.','fourthDownConv.','timeOfPossession','playerPassing'])

# %% [markdown]
# ## Loop through all of the pages and scrape the data
# ### Then insert into dataframe

# %%
# Create empty lists for values to scrape
gameInfo = []
teamStats = []
scores = []
records = []
gameDetails = []
passingStats = []
# Begin scraping the pages
for game in gameURLs:
    request = requests.get(game)
    sleep(3)
    # Generate the soup
    soup = BeautifulSoup(request.content, 'html.parser')
    # Get Game Info Table
    game_info = soup.find(id='all_game_info')
    gi_children = list(game_info.children)
    gi_table = gi_children[4]
    gi_data = BeautifulSoup(gi_table, 'html.parser')
    for tr in gi_data.select("tr"):
        gameInfo.append(tr.get_text(strip=True,separator=":"))
    # Get Team Stats Table
    stats = soup.find(id="all_team_stats")
    statsResults = list(stats.children)
    statsTable = statsResults[4]
    statsData = BeautifulSoup(statsTable, 'html.parser')
    for tr in statsData.select("tr"):
        teamStats.append(tr.get_text(strip=True, separator=':'))
    # Find the Score of the Games
    for score in soup.find_all(class_="score"):
        scores.append(score.get_text())
    # Find the teams records
    scorebox = soup.find(class_="scorebox")
    homeTeam = scorebox.select("div")[5]
    records.append(homeTeam.get_text())
    awayTeam = scorebox.select("div")[13]
    records.append(awayTeam.get_text())
    # Get the Game Details
    details = soup.find(class_="scorebox_meta")
    for detail in details.select("div")[0:3]:
        gameDetails.append(detail.get_text())
    # Get the Player Stats Table
    passingTable = soup.find(id='player_offense')
    for tr in passingTable.select('tr'):
        passingStats.append(tr.get_text(strip=True,separator=':'))
    # Append data to the dataframe
    if len(gameInfo) == 9:
        df = df.append({'wonToss':gameInfo[1],'roof':gameInfo[2],'surface':gameInfo[3],'attendance':gameInfo[5],
                   'weather':gameInfo[6],'vegasLine':gameInfo[7],'over/under':gameInfo[8],'homeScore':scores[0],
                   'awayScore':scores[1],'homeRecord':records[0],'awayRecord':records[1],'date':gameDetails[0],
                   'time':gameDetails[1],'stadium':gameDetails[2],'teams(away:home)':teamStats[0],
                   'firstDowns':teamStats[1],'rush-yds-tds':teamStats[2],'cmp-att-yd-td-int':teamStats[3],
                   'sacked-yrds':teamStats[4],'passYards':teamStats[5],'totalYards':teamStats[6],
                   'fumbles-lost':teamStats[7],'turnovers':teamStats[8],'penalties-yrds':teamStats[9],
                   'thirdDownConv.':teamStats[10],'fourthDownConv.':teamStats[11],
                   'timeOfPossession':teamStats[12],'playerPassing':passingStats},ignore_index=True)
    elif len(gameInfo) == 8:
        df = df.append({'wonToss':gameInfo[1],'roof':gameInfo[2],'surface':gameInfo[3],'attendance':gameInfo[5],
                   'weather':'','vegasLine':gameInfo[6],'over/under':gameInfo[7],'homeScore':scores[0],
                   'awayScore':scores[1],'homeRecord':records[0],'awayRecord':records[1],'date':gameDetails[0],
                   'time':gameDetails[1],'stadium':gameDetails[2],'teams(away:home)':teamStats[0],
                   'firstDowns':teamStats[1],'rush-yds-tds':teamStats[2],'cmp-att-yd-td-int':teamStats[3],
                   'sacked-yrds':teamStats[4],'passYards':teamStats[5],'totalYards':teamStats[6],
                   'fumbles-lost':teamStats[7],'turnovers':teamStats[8],'penalties-yrds':teamStats[9],
                   'thirdDownConv.':teamStats[10],'fourthDownConv.':teamStats[11],
                   'timeOfPossession':teamStats[12],'playerPassing':passingStats},ignore_index=True)
    # Empty lists for new rows of data
    gameInfo = []
    teamStats = []
    scores = []
    records = []
    gameDetails = []
    passingStats = []

# %% [markdown]
# ## Show dataframe

# %%
df
# Out:
#                           wonToss                            roof  \
# 0    Won Toss:Patriots (deferred)                   Roof:outdoors
# 1     Won Toss:Packers (deferred)                   Roof:outdoors
# 2        Won Toss:Rams (deferred)                Won OT Toss:Rams
# 3      Won Toss:Texans (deferred)  Roof:retractable roof (closed)
# 4    Won Toss:Dolphins (deferred)                   Roof:outdoors
# ..                            ...                             ...
# 763                Won Toss:Colts                   Roof:outdoors
# 764  Won Toss:Panthers (deferred)                   Roof:outdoors
# 765   Won Toss:Broncos (deferred)                   Roof:outdoors
# 766   Won Toss:Broncos (deferred)                   Roof:outdoors
# 767     Won Toss:49ers (deferred)                   Roof:outdoors
#
#                surface         attendance  \
# 0    Surface:fieldturf  Attendance:66,829
# 1        Surface:grass  Attendance:62,442
# 2            Roof:dome      Duration:3:30
# 3        Surface:grass  Attendance:71,776
# 4        Surface:grass  Attendance:76,512
# ..                 ...                ...
# 763  Surface:fieldturf  Attendance:68,756
# 764      Surface:grass  Attendance:73,784
# 765      Surface:grass  Attendance:76,969
# 766      Surface:grass  Attendance:77,110
# 767  Surface:fieldturf  Attendance:68,454
#
#                                                weather  \
# 0    Weather:65 degrees, relative humidity 0%, wind...
# 1    Weather:72 degrees, relative humidity 39%, win...
# 2                                    Attendance:51,792
# 3
# 4    Weather:69 degrees, relative humidity 58%, win...
# ..                                                 ...
# 763  Weather:57 degrees, relative humidity 100%, wi...
# 764  Weather:54 degrees, relative humidity 42%, win...
# 765  Weather:41 degrees, relative humidity 20%, win...
# 766  Weather:63 degrees, relative humidity 10%, win...
# 767  Weather:43 degrees, relative humidity 88%, win...
#
#                                 vegasLine               over/under homeScore  \
# 0    Vegas Line:New England Patriots -7.0  Over/Under:52.0:(under)        28
# 1       Vegas Line:Green Bay Packers -6.5   Over/Under:49.0:(over)        23
# 2        Vegas Line:Seattle Seahawks -4.0   Over/Under:40.5:(over)        34
# 3          Vegas Line:Houston Texans -1.0   Over/Under:41.0:(over)        20
# 4          Vegas Line:Miami Dolphins -3.0  Over/Under:43.5:(under)        10
# ..                                    ...                      ...       ...
# 763  Vegas Line:New England Patriots -7.0   Over/Under:51.0:(over)        43
# 764   Vegas Line:San Francisco 49ers -1.0  Over/Under:41.0:(under)        10
# 765        Vegas Line:Denver Broncos -7.5  Over/Under:55.0:(under)        24
# 766        Vegas Line:Denver Broncos -5.0  Over/Under:56.5:(under)        26
# 767      Vegas Line:Seattle Seahawks -4.0  Over/Under:40.5:(under)        23
#
#     awayScore homeRecord  ...                              cmp-att-yd-td-int  \
# 0          21        1-0  ...  Cmp-Att-Yd-TD-INT:26-38-351-1-1:25-32-288-4-0
# 1          31        0-1  ...  Cmp-Att-Yd-TD-INT:18-23-189-3-0:18-36-225-1-1
# 2          31        1-0  ...  Cmp-Att-Yd-TD-INT:32-41-251-1-1:18-27-297-1-0
# 3          27        0-1  ...  Cmp-Att-Yd-TD-INT:22-33-243-3-0:26-47-334-2-1
# 4          17        0-1  ...  Cmp-Att-Yd-TD-INT:22-34-226-1-0:21-31-196-1-2
# ..        ...        ...  ...                                            ...
# 763        22       13-4  ...  Cmp-Att-Yd-TD-INT:20-41-331-2-4:13-25-198-0-0
# 764        23       12-5  ...  Cmp-Att-Yd-TD-INT:15-30-196-1-0:16-25-267-1-2
# 765        17       14-3  ...  Cmp-Att-Yd-TD-INT:18-27-217-2-0:25-36-230-2-1
# 766        16       15-3  ...  Cmp-Att-Yd-TD-INT:24-38-277-1-0:32-43-400-2-0
# 767        17       15-3  ...  Cmp-Att-Yd-TD-INT:14-24-153-1-2:16-25-215-1-0
#
#                 sacked-yrds               passYards           totalYards  \
# 0     Sacked-Yards:3-21:2-7  Net Pass Yards:330:281  Total Yards:464:361
# 1     Sacked-Yards:0-0:2-12  Net Pass Yards:189:213  Total Yards:322:402
# 2    Sacked-Yards:6-32:2-21  Net Pass Yards:219:276  Total Yards:343:352
# 3    Sacked-Yards:2-10:5-36  Net Pass Yards:233:298  Total Yards:330:396
# 4     Sacked-Yards:3-44:1-8  Net Pass Yards:182:188  Total Yards:256:349
# ..                      ...                     ...                  ...
# 763  Sacked-Yards:3-14:2-13  Net Pass Yards:317:185  Total Yards:386:419
# 764   Sacked-Yards:1-7:5-35  Net Pass Yards:189:232  Total Yards:315:325
# 765   Sacked-Yards:4-23:0-0  Net Pass Yards:194:230  Total Yards:259:363
# 766   Sacked-Yards:2-21:0-0  Net Pass Yards:256:400  Total Yards:320:507
# 767   Sacked-Yards:2-6:4-22  Net Pass Yards:147:193  Total Yards:308:308
#
#              fumbles-lost      turnovers              penalties-yrds  \
# 0    Fumbles-Lost:0-0:1-0  Turnovers:1:0   Penalties-Yards:8-77:7-64
# 1    Fumbles-Lost:0-0:0-0  Turnovers:0:1  Penalties-Yards:10-74:6-64
# 2    Fumbles-Lost:0-0:3-3  Turnovers:1:3   Penalties-Yards:7-46:4-30
# 3    Fumbles-Lost:1-0:2-1  Turnovers:0:2   Penalties-Yards:2-25:6-39
# 4    Fumbles-Lost:2-1:1-0  Turnovers:1:2  Penalties-Yards:6-39:11-88
# ..                    ...            ...                         ...
# 763  Fumbles-Lost:0-0:3-0  Turnovers:4:0   Penalties-Yards:4-42:4-35
# 764  Fumbles-Lost:1-0:0-0  Turnovers:0:2   Penalties-Yards:5-40:8-73
# 765  Fumbles-Lost:0-0:1-1  Turnovers:0:2   Penalties-Yards:8-63:6-50
# 766  Fumbles-Lost:0-0:0-0  Turnovers:0:0   Penalties-Yards:2-15:4-34
# 767  Fumbles-Lost:3-1:3-1  Turnovers:3:1   Penalties-Yards:7-65:8-66
#
#                   thirdDownConv.            fourthDownConv.  \
# 0     Third Down Conv.:7-15:7-11  Fourth Down Conv.:2-2:0-0
# 1    Third Down Conv.:6-10:11-17  Fourth Down Conv.:1-1:2-3
# 2     Third Down Conv.:8-19:6-11  Fourth Down Conv.:1-2:0-0
# 3     Third Down Conv.:3-13:3-14  Fourth Down Conv.:0-0:0-1
# 4     Third Down Conv.:5-12:6-14  Fourth Down Conv.:0-1:0-1
# ..                           ...                        ...
# 763  Third Down Conv.:6-15:11-18  Fourth Down Conv.:1-1:0-1
# 764   Third Down Conv.:6-14:6-10  Fourth Down Conv.:0-1:0-1
# 765   Third Down Conv.:4-12:9-13  Fourth Down Conv.:1-1:0-0
# 766   Third Down Conv.:6-12:7-13  Fourth Down Conv.:1-2:1-1
# 767   Third Down Conv.:3-11:5-14  Fourth Down Conv.:2-2:1-3
#
#                    timeOfPossession
# 0    Time of Possession:32:05:27:55
# 1    Time of Possession:28:08:31:52
# 2    Time of Possession:37:28:28:32
# 3    Time of Possession:35:19:24:41
# 4    Time of Possession:22:06:37:54
# ..                              ...
# 763  Time of Possession:25:00:35:00
# 764  Time of Possession:29:55:30:05
# 765  Time of Possession:24:33:35:27
# 766  Time of Possession:24:16:35:44
# 767  Time of Possession:28:32:31:28
#
# [768 rows x 27 columns]

# %% [markdown]
# ## Save CSV to desktop

# %%
nflData = df.to_csv(r'Desktop\nflData.csv')
